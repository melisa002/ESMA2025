# %%
# !pip install git+https://github.com/European-Securities-Markets-Authority/esma_data_py.git
# Out:
# Collecting git+https://github.com/European-Securities-Markets-Authority/esma_data_py.git
#   Cloning https://github.com/European-Securities-Markets-Authority/esma_data_py.git to /private/var/folders/v1/v83gn92x7vv8phs46b_nj2gr0000gn/T/pip-req-build-t_k0zs06
#   Running command git clone --filter=blob:none --quiet https://github.com/European-Securities-Markets-Authority/esma_data_py.git /private/var/folders/v1/v83gn92x7vv8phs46b_nj2gr0000gn/T/pip-req-build-t_k0zs06
#   Resolved https://github.com/European-Securities-Markets-Authority/esma_data_py.git to commit 204a3d895a4b9dbe5b21268ef11b4d392eb58a21
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=2.0.0 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from esma_data_py==0.0.1) (2.2.3)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from esma_data_py==0.0.1) (4.67.1)
# Requirement already satisfied: requests>=2.31.0 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from esma_data_py==0.0.1) (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from pandas>=2.0.0->esma_data_py==0.0.1) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from pandas>=2.0.0->esma_data_py==0.0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from pandas>=2.0.0->esma_data_py==0.0.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from pandas>=2.0.0->esma_data_py==0.0.1) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from requests>=2.31.0->esma_data_py==0.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from requests>=2.31.0->esma_data_py==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from requests>=2.31.0->esma_data_py==0.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from requests>=2.31.0->esma_data_py==0.0.1) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/datasci/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->esma_data_py==0.0.1) (1.16.0)
# Building wheels for collected packages: esma_data_py
#   Building wheel for esma_data_py (setup.py) ... done
#   Created wheel for esma_data_py: filename=esma_data_py-0.0.1-py3-none-any.whl size=17228 sha256=ab1f5cdac3f0b8a949d067cdd6b958139aae53d6a7c4f9c6420db98d3a04b2d5
#   Stored in directory: /private/var/folders/v1/v83gn92x7vv8phs46b_nj2gr0000gn/T/pip-ephem-wheel-cache-sjugcs5h/wheels/2b/8f/ba/a7253468efe05cef4ed14fb56fc2aa6132e30c0e0fc9c2ad0f
# Successfully built esma_data_py
# Installing collected packages: esma_data_py
# Successfully installed esma_data_py-0.0.1

# %%
from  esma_data_py import EsmaDataLoader
edl = EsmaDataLoader()
list_files = edl.load_mifid_file_list()
list_files
# Out:
# 2025-04-27 18:35:35,603 - EsmaDataLoader - INFO - Loading 3 datasets
# 2025-04-27 18:35:35,603 - EsmaDataLoader - INFO - Loading dvcap dataset
# 2025-04-27 18:35:35,603 - EsmaDataLoader - INFO - Requesting dvcap files
# 2025-04-27 18:35:36,083 - EsmaDataLoader - INFO - Request successful, parsing response
# 2025-04-27 18:35:36,104 - EsmaDataLoader - INFO - Loading fitrs dataset
# 2025-04-27 18:35:36,105 - EsmaDataLoader - INFO - Requesting fitrs files
# 2025-04-27 18:35:39,529 - EsmaDataLoader - INFO - Request successful, parsing response
# 2025-04-27 18:35:40,857 - EsmaDataLoader - INFO - Loading firds dataset
# 2025-04-27 18:35:40,857 - EsmaDataLoader - INFO - Requesting firds files
# 2025-04-27 18:35:44,532 - EsmaDataLoader - INFO - Request successful, parsing response
# 2025-04-27 18:35:45,935 - EsmaDataLoader - INFO - Process done!
#       type_s                                      download_link _root_     id  \
# 0     parent  https://dvcap.esma.europa.eu/dvcap/DVCRES_2022...   1181   1181
# 1     parent  https://dvcap.esma.europa.eu/dvcap/DVCRES_2023...   1421   1421
# 2     parent  https://dvcap.esma.europa.eu/dvcap/DVCRES_2024...   1662   1662
# 3     parent  https://dvcap.esma.europa.eu/dvcap/DVCRES_2024...   1742   1742
# 4     parent  https://dvcap.esma.europa.eu/dvcap/DVCRES_2025...   1862   1862
# ...      ...                                                ...    ...    ...
# 9995     NaN  https://firds.esma.europa.eu/firds/DLTINS_2022...  56409  56409
# 9996     NaN  https://firds.esma.europa.eu/firds/FULCAN_2022...  56415  56415
# 9997     NaN  https://firds.esma.europa.eu/firds/FULINS_R_20...  57010  57010
# 9998     NaN  https://firds.esma.europa.eu/firds/FULINS_R_20...  57011  57011
# 9999     NaN  https://firds.esma.europa.eu/firds/FULINS_R_20...  57012  57012
#
#              creation_date                            base_url  \
# 0     2022-03-07T18:00:23Z  https://dvcap.esma.europa.eu/dvcap
# 1     2023-02-07T18:01:50Z  https://dvcap.esma.europa.eu/dvcap
# 2     2024-03-07T18:03:19Z  https://dvcap.esma.europa.eu/dvcap
# 3     2024-07-05T18:02:11Z  https://dvcap.esma.europa.eu/dvcap
# 4     2025-01-09T18:02:33Z  https://dvcap.esma.europa.eu/dvcap
# ...                    ...                                 ...
# 9995                   NaN                                 NaN
# 9996                   NaN                                 NaN
# 9997                   NaN                                 NaN
# 9998                   NaN                                 NaN
# 9999                   NaN                                 NaN
#
#                          file_name            _version_  \
# 0              DVCRES_20220307.zip  1828767962802159616
# 1              DVCRES_20230207.zip  1828767962816839680
# 2              DVCRES_20240307.zip  1828767962816839681
# 3              DVCRES_20240705.zip  1828767962817888256
# 4              DVCRES_20250109.zip  1828767962817888257
# ...                            ...                  ...
# 9995    DLTINS_20220219_03of03.zip  1830520034337751047
# 9996    FULCAN_20220219_01of01.zip  1830520034337751048
# 9997  FULINS_R_20220312_02of06.zip  1830520034337751049
# 9998  FULINS_R_20220312_03of06.zip  1830520034337751050
# 9999  FULINS_R_20220312_04of06.zip  1830520034337751051
#
#                      timestamp instrument_type file_type  \
# 0     2025-04-07T18:03:56.805Z             NaN       NaN
# 1     2025-04-07T18:03:56.805Z             NaN       NaN
# 2     2025-04-07T18:03:56.805Z             NaN       NaN
# 3     2025-04-07T18:03:56.806Z             NaN       NaN
# 4     2025-04-07T18:03:56.806Z             NaN       NaN
# ...                        ...             ...       ...
# 9995  2025-04-27T02:12:22.415Z             NaN    DLTINS
# 9996  2025-04-27T02:12:22.415Z             NaN    FULCAN
# 9997  2025-04-27T02:12:22.415Z             NaN    FULINS
# 9998  2025-04-27T02:12:22.415Z             NaN    FULINS
# 9999  2025-04-27T02:12:22.415Z             NaN    FULINS
#
#           publication_date published_instrument_file_id  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# ...                    ...                          ...
# 9995  2022-02-19T00:00:00Z                        56409
# 9996  2022-02-19T00:00:00Z                        56415
# 9997  2022-03-12T00:00:00Z                        57010
# 9998  2022-03-12T00:00:00Z                        57011
# 9999  2022-03-12T00:00:00Z                        57012
#
#                               checksum
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 9995  b82815673401a2ff1154a5a3eff7081a
# 9996  ca04863ee50e7929a03d7a74a411e3c4
# 9997  aaade54a425da7b95eda98ab81010fb7
# 9998  3f3eb4f00bd79f5b388aa7c5104afd44
# 9999  48d60c5fbeafd7df435135e947e65151
#
# [20041 rows x 14 columns]

# %%
import pandas as pd
cs1 = pd.read_csv('exp/export.csv')
cs2 = pd.read_csv('exp/export(1).csv')
cs3 = pd.read_csv('exp/export(2).csv')
cs4 = pd.read_csv('exp/export(3).csv')
cs5 = pd.read_csv('exp/export(4).csv')

comp = pd.concat([cs1, cs2, cs3, cs4, cs5], axis=0)
comp.head(10)
# Out:
#          Prospectus Type                                      Document Type  \
# 0        Base Prospectus  Final terms, including the  summary of the ind...
# 1        Base Prospectus  Final terms, including the  summary of the ind...
# 2        Base Prospectus  Final terms, including the  summary of the ind...
# 3        Base Prospectus  Final terms, including the  summary of the ind...
# 4        Base Prospectus  Final terms, including the  summary of the ind...
# 5        Base Prospectus  Final terms, including the  summary of the ind...
# 6        Base Prospectus  Final terms, including the  summary of the ind...
# 7        Base Prospectus  Final terms, including the  summary of the ind...
# 8  Standalone Prospectus                              Standalone prospectus
# 9  Standalone Prospectus                              Standalone prospectus
#
#   Last Passporting Date Approval or filing date Home Member State  \
# 0                   NaN              24/05/2025           CZECHIA
# 1                   NaN              24/04/2025           CZECHIA
# 2                   NaN              24/04/2025           CZECHIA
# 3                   NaN              24/04/2025           CZECHIA
# 4                   NaN              24/04/2025           CZECHIA
# 5                   NaN              24/04/2025           CZECHIA
# 6                   NaN              24/04/2025           CZECHIA
# 7                   NaN              24/04/2025           CZECHIA
# 8                   NaN              22/04/2025           CZECHIA
# 9                   NaN              22/04/2025           CZECHIA
#
#                      Securities Type          ISIN First Passporting Date  \
# 0  Debt with denomination < €100.000  CZ0003572414                    NaN
# 1  Debt with denomination < €100.000  CZ0003572273                    NaN
# 2  Debt with denomination < €100.000  CZ0003572422                    NaN
# 3  Debt with denomination < €100.000  CZ0003572406                    NaN
# 4  Debt with denomination < €100.000  CZ0003572042                    NaN
# 5  Debt with denomination < €100.000  CZ0003572059                    NaN
# 6  Debt with denomination < €100.000  CZ0003572075                    NaN
# 7  Debt with denomination < €100.000  CZ0003572067                    NaN
# 8                             Shares  CZ0009013272                    NaN
# 9                             Shares  CZ1008000831                    NaN
#
#   Last Update Date National Document ID        Consideration offered  \
# 0       26/04/2025           FTWS664847                Max 340000000
# 1       25/04/2025           FTWS663992                Max 100000000
# 2       26/04/2025           FTWS664848                Max 200000000
# 3       26/04/2025           FTWS664849                Max 200000000
# 4       26/04/2025           FTWS664853                 Max 50000000
# 5       26/04/2025           FTWS665000                Max 150000000
# 6       26/04/2025           FTWS665001                  Max 1000000
# 7       26/04/2025           FTWS664999                Max 100000000
# 8       24/04/2025           STDA100844  From 160140000 to 266900000
# 9       24/04/2025           STDA100844  From 120000000 to 600000000
#
#                                 Issuer(s) Name / LEI Host Member State(s)
# 0  Českomoravská Projektová VII a.s. - 31570006FB...                  NaN
# 1           WOOD SEEDS s.r.o. - 3157004CFGD745LKYZ81                  NaN
# 2  Českomoravská Projektová VII a.s. - 31570006FB...                  NaN
# 3  Českomoravská Projektová VII a.s. - 31570006FB...                  NaN
# 4    BICZ Bond 2024 CR s.r.o. - 3157006C8O37QWMV6H25                  NaN
# 5    BICZ Bond 2024 CR s.r.o. - 3157006C8O37QWMV6H25                  NaN
# 6    BICZ Bond 2024 CR s.r.o. - 3157006C8O37QWMV6H25                  NaN
# 7    BICZ Bond 2024 CR s.r.o. - 3157006C8O37QWMV6H25                  NaN
# 8      ALEMAR Food Group a.s. - 315700L63KOVVLIKGM26                  NaN
# 9      ALEMAR Food Group a.s. - 315700L63KOVVLIKGM26                  NaN
